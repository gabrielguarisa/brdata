# %%
crawler = CVMCrawler()
crawler.get_documents("FRE", 2018, 2022)
# Out:
# Invalid file fre_cia_aberta_remuneracao_total_orgao Error tokenizing data. C error: Expected 26 fields in line 3327, saw 36
#
# Invalid file fre_cia_aberta_ativo_intangivel Error tokenizing data. C error: Expected 9 fields in line 3012, saw 11
#
# Invalid file fre_cia_aberta_transacao_parte_relacionada Error tokenizing data. C error: Expected 21 fields in line 5781, saw 25
#
# Invalid file fre_cia_aberta_ativo_intangivel Error tokenizing data. C error: Expected 9 fields in line 4052, saw 11
#
# Invalid file fre_cia_aberta_relacao_familiar Error tokenizing data. C error: Expected 16 fields in line 29, saw 23
#
# Invalid file fre_cia_aberta_transacao_parte_relacionada Error tokenizing data. C error: Expected 21 fields in line 737, saw 25
#
# Invalid file fre_cia_aberta_relacao_familiar Error tokenizing data. C error: Expected 16 fields in line 40, saw 23
#
# Invalid file fre_cia_aberta_outro_valor_mobiliario Error tokenizing data. C error: Expected 23 fields in line 3810, saw 25
# ...
